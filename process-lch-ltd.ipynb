# %% [markdown]
# Import Required Libraries and Load Configuration Files

# %%
# # Import required libraries  
import os  
import base64
from pathlib import Path
from shutil import rmtree
from requests import get, post
import json
import time
import copy 
from datetime import datetime, timedelta  
import pdfkit
from langchain.text_splitter import TokenTextSplitter, MarkdownHeaderTextSplitter


from openai import AzureOpenAI
from azure.ai.documentintelligence import DocumentIntelligenceClient
from azure.ai.documentintelligence.models import AnalyzeResult
from azure.identity import DefaultAzureCredential, get_bearer_token_provider

# %%
#Load the configuration details for the Cognitive Search Service and Azure OpenAI Instance
#Credentials should be secured using a more secure method such as Azure KeyVault
config = json.load(open("config.json"))

# %% [markdown]
# Create Azure OpenAI and Document Intelligent (Pre-Built Layout) Instances. Set Chunking Config to split on Markdown Headers

# %%
#Azure OpenAI
api_base = config["openai_api_base"]
api_key = config["openai_api_key"]
openai_api_version = config["openai_api_version"]
embeddings_model = config["openai_embedding_model"]
gpt_model = config["openai_gpt_model"] 

# Doc Intelligence Config
di_endpoint = config["doc_intelligence_endpoint"]
di_apim_key = config["doc_intelligence_apim_key"]
di_headers = {
    'Content-Type': 'application/pdf',
    'Ocp-Apim-Subscription-Key': di_apim_key,
}
di_post_url = di_endpoint + "documentintelligence/documentModels/prebuilt-layout:analyze?api-version=2023-10-31-preview&stringIndexType=utf16CodeUnit&outputContentFormat=markdown"
credential = DefaultAzureCredential()

# Chunking Config
text_splitter = TokenTextSplitter(chunk_size=512, chunk_overlap=52)  
headers_to_split_on = [
    ("#", "Header 1"),
    ("##", "Header 2"),
    ("###", "Header 3"),
]
markdown_splitter = MarkdownHeaderTextSplitter(headers_to_split_on=headers_to_split_on)


# gets the API Key from environment variable AZURE_OPENAI_API_KEY
client = AzureOpenAI(
    api_version=openai_api_version,
    azure_endpoint=api_base,
    api_key=api_key)

document_intelligence_client = DocumentIntelligenceClient(
    endpoint=di_endpoint,
    credential=credential
)

# %% [markdown]
# Load Files in 'Data' Folder, Test Layout Analysis on ISDA-2.pdf

# %%
data_root_dir = config["data_root_dir"]

# Get all files in dir
def get_files_in_dir(in_dir):
    return [os.path.join(dp, f) for dp, dn, filenames in os.walk(in_dir) for f in filenames]

files = get_files_in_dir(data_root_dir)

# %%
for local_file in files:
    
    file_type = os.path.splitext(local_file)[1].lower()
    if file_type != ".pdf":
        continue

    if local_file != "data\lch_ltd_formatted_template-v2.pdf":
        continue
    
    else:
        print("Analyzing %s" % local_file)
        
    with open(local_file, "rb") as f:
        data_bytes = f.read()
    
    
        resp = post(url = di_post_url, data = data_bytes, headers = di_headers)
        if resp.status_code != 202:
            print("POST analyze failed:\n%s" % resp.text)
            quit()
        print("POST analyze succeeded:\n%s" % resp.headers)
        get_url = resp.headers["operation-location"]
        print (get_url)
            
        n_tries = 10
        n_try = 0
        wait_sec = 2
        processing = True
        while processing:
            try:
                resp = get(url = get_url, headers = {"Ocp-Apim-Subscription-Key": di_apim_key})
                resp_json = json.loads(resp.text)
                if resp.status_code != 200:
                    print("GET Layout results failed:\n")
                    processing = False
                elif resp_json["status"] == "succeeded":
                    print("Layout Analysis succeeded:\n")
                    print("--------------------------------")
                    processing = False
                elif resp_json["status"] == "failed":
                    # print("Layout Analysis failed:\n%s" % resp_json)
                    print("Layout Analysis failed:\n")
                    processing = False
                else:
                    # Analysis still running. Wait and retry.
                    print ('Waiting to complete processing...')
                    time.sleep(wait_sec)
            except Exception as e:
                msg = "GET analyze results failed:\n%s" % str(e)
                print(msg)
                processing = False
            
    # Persist the Doc Int Output for further processing
    if 'analyzeResult' in resp_json:
        resp = resp_json['analyzeResult']
    
        break
# Out:
# Analyzing data\lch_ltd_formatted_template-v2.pdf
# POST analyze succeeded:
# {'Content-Length': '0', 'Operation-Location': 'https://klau-docintel.cognitiveservices.azure.com/documentintelligence/documentModels/prebuilt-layout/analyzeResults/387955ca-4c2c-4d46-8888-df81bad47873?api-version=2023-10-31-preview', 'x-envoy-upstream-service-time': '105', 'apim-request-id': '387955ca-4c2c-4d46-8888-df81bad47873', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'x-content-type-options': 'nosniff', 'x-ms-region': 'East US', 'Date': 'Mon, 10 Mar 2025 17:06:32 GMT'}
# https://klau-docintel.cognitiveservices.azure.com/documentintelligence/documentModels/prebuilt-layout/analyzeResults/387955ca-4c2c-4d46-8888-df81bad47873?api-version=2023-10-31-preview
# Waiting to complete processing...
# Waiting to complete processing...
# Layout Analysis succeeded:
#
# --------------------------------

# %% [markdown]
# Print Tables Found

# %%
for table_idx, table in enumerate(resp["tables"]):
    print(
        "Table # {} has {} rows and {} columns".format(
        table_idx, table["rowCount"], table["columnCount"]
        )
    )
        
    for cell in table["cells"]:
        print(
            "...Cell[{}][{}] has content '{}'".format(
            cell["rowIndex"],
            cell["columnIndex"],
            cell["content"]),
            )
# Out:
# Table # 0 has 51 rows and 4 columns
# ...Cell[0][0] has content 'Country'
# ...Cell[0][1] has content 'Government Securities (Description & Bloomberg Code)'
# ...Cell[0][2] has content 'Term'
# ...Cell[0][3] has content 'Haircut (Conventional Bonds)'
# ...Cell[1][0] has content 'Australia'
# ...Cell[1][1] has content 'Australian Treasury Bill'
# ...Cell[1][2] has content '5 business days <= 2yr'
# ...Cell[1][3] has content '0.78%'
# ...Cell[2][1] has content '(ACTB)'
# ...Cell[2][2] has content '> 2yr <= 5yrs'
# ...Cell[2][3] has content '1.23%'
# ...Cell[3][1] has content 'Australian Government Bond'
# ...Cell[3][2] has content '> 5yrs <= 7 yrs'
# ...Cell[3][3] has content '2.50%'
# ...Cell[4][1] has content '(ACGB)'
# ...Cell[4][2] has content '>7yrs <= 10yrs'
# ...Cell[4][3] has content '3.75%'
# ...Cell[5][1] has content 'Australian Government I/L'
# ...Cell[5][2] has content '>10yrs <= 40yrs'
# ...Cell[5][3] has content '9.25%'
# ...Cell[6][1] has content '(ACGB)'
# ...Cell[6][2] has content '>40yrs <= 60yrs'
# ...Cell[6][3] has content '10.35%'
# ...Cell[7][0] has content 'Austria'
# ...Cell[7][1] has content 'Austrian Treasury Bill'
# ...Cell[7][2] has content '18 business days <= 1yr'
# ...Cell[7][3] has content '0.45%'
# ...Cell[8][1] has content '(RATB)'
# ...Cell[8][2] has content '>1yr <= 4yrs'
# ...Cell[8][3] has content '1.75%'
# ...Cell[9][1] has content 'Austrian Government Bond'
# ...Cell[9][2] has content '>4yrs <= 8 yrs'
# ...Cell[9][3] has content '2.85%'
# ...Cell[10][1] has content '(RAGB)'
# ...Cell[10][2] has content '>8yrs <= 12yrs'
# ...Cell[10][3] has content '3.25%'
# ...Cell[11][1] has content 'Austria International Bond (AUST)'
# ...Cell[11][2] has content ''
# ...Cell[11][3] has content ''
# ...Cell[12][3] has content ''
# ...Cell[13][0] has content 'Belgium'
# ...Cell[13][1] has content 'Belgian Treasury Bill (BGTB)'
# ...Cell[13][2] has content '6 business days <= 1yr'
# ...Cell[13][3] has content '0.89%'
# ...Cell[14][1] has content 'Belgian Government Bond'
# ...Cell[14][2] has content '>1yr <= 2yrs'
# ...Cell[14][3] has content '1.96%'
# ...Cell[15][1] has content '(BGB)'
# ...Cell[15][2] has content '> 2yrs <= 5 yrs'
# ...Cell[15][3] has content '3.65%'
# ...Cell[16][1] has content ''
# ...Cell[16][2] has content '> 5yrs <= 8yrs'
# ...Cell[16][3] has content '5.68%'
# ...Cell[17][1] has content ''
# ...Cell[17][2] has content '> 8yrs <= 17yrs'
# ...Cell[17][3] has content '8.00%'
# ...Cell[18][1] has content ''
# ...Cell[18][2] has content '> 17yrs <= 55yrs'
# ...Cell[18][3] has content '13.75%'
# ...Cell[19][0] has content 'Canada'
# ...Cell[19][1] has content 'Canadian Treasury Bill (CTB)'
# ...Cell[19][2] has content '15 calendar days <= 2yr'
# ...Cell[19][3] has content '0.97%'
# ...Cell[20][1] has content 'Canadian Government Bond'
# ...Cell[20][2] has content '> 2yr <= 5yrs'
# ...Cell[20][3] has content '1.37%'
# ...Cell[21][1] has content '(CAN)'
# ...Cell[21][2] has content '> 5yrs <= 8yrs'
# ...Cell[21][3] has content '2.56%'
# ...Cell[22][1] has content 'Canada Government Real'
# ...Cell[22][2] has content '>8yrs <= 10yrs'
# ...Cell[22][3] has content '3.79%'
# ...Cell[23][1] has content 'Return Bond (CAN)'
# ...Cell[23][2] has content '> 10yrs <= 35yrs'
# ...Cell[23][3] has content '7.85%'
# ...Cell[24][0] has content 'Denmark'
# ...Cell[24][1] has content 'Danish Treasury Bill (DGTB)'
# ...Cell[24][2] has content '8 business days <= 2yr'
# ...Cell[24][3] has content '0.58%'
# ...Cell[25][1] has content 'Danish Government Bond'
# ...Cell[25][2] has content '> 2yr <= 6yrs'
# ...Cell[25][3] has content '1.69%'
# ...Cell[26][1] has content '(DGB)'
# ...Cell[26][2] has content '>6yrs <= 9yrs'
# ...Cell[26][3] has content '2.58%'
# ...Cell[27][1] has content 'Danish Government I/L'
# ...Cell[27][2] has content '>9yrs <= 13yrs'
# ...Cell[27][3] has content '2.73%'
# ...Cell[28][1] has content '(DGBI)'
# ...Cell[28][2] has content '>13yrs <= 40yrs'
# ...Cell[28][3] has content '10.52%'
# ...Cell[29][1] has content ''
# ...Cell[29][2] has content '> 40yrs <= 60yrs'
# ...Cell[29][3] has content '6.87%'
# ...Cell[30][0] has content 'Finland'
# ...Cell[30][1] has content 'Finnish Treasury Bill (RFTB)'
# ...Cell[30][2] has content '6 business days <= 2yr'
# ...Cell[30][3] has content '0.38%'
# ...Cell[31][1] has content 'Finnish Government Bonds'
# ...Cell[31][2] has content '> 2yr <= 3yrs'
# ...Cell[31][3] has content '1.68%'
# ...Cell[32][1] has content '(RFGB)'
# ...Cell[32][2] has content '>3yrs <= 7 yrs'
# ...Cell[32][3] has content '2.71%'
# ...Cell[33][1] has content ''
# ...Cell[33][2] has content '>7yrs <= 12yrs'
# ...Cell[33][3] has content '3.62%'
# ...Cell[34][1] has content ''
# ...Cell[34][2] has content '> 12yrs <= 45yrs'
# ...Cell[34][3] has content '10.86%'
# ...Cell[35][1] has content ''
# ...Cell[35][2] has content '> 45yrs <= 65yrs'
# ...Cell[35][3] has content '13.98%'
# ...Cell[36][0] has content 'France'
# ...Cell[36][1] has content 'Bons du Trésor à Taux Fixe et'
# ...Cell[36][2] has content '6 business days <= 2yr'
# ...Cell[36][3] has content '0.47%'
# ...Cell[37][1] has content 'Intérêt Précompté (BTF)'
# ...Cell[37][2] has content '>2yr <= 3yrs'
# ...Cell[37][3] has content '1.89%'
# ...Cell[38][1] has content 'Bons du Trésor à Taux Fixe et'
# ...Cell[38][2] has content '>3yrs <= 7 yrs'
# ...Cell[38][3] has content '3.55%'
# ...Cell[39][1] has content 'Intérêt Annuel (BTNS)'
# ...Cell[39][2] has content '> 7yrs <= 13yrs'
# ...Cell[39][3] has content '12.66%'
# ...Cell[40][1] has content 'Bons du Trésor à Taux Fixe et'
# ...Cell[40][2] has content '>13yrs <= 45yrs'
# ...Cell[40][3] has content '14.88%'
# ...Cell[41][1] has content 'Intérêt Annuel I/L (BTNS) Obligations Assimilables du Trésor (FRTR)'
# ...Cell[41][2] has content '> 45yrs <= 65yrs'
# ...Cell[41][3] has content '16.44%'
# ...Cell[42][3] has content ''
# ...Cell[43][1] has content 'Obligations Assimilables du Trésor I/L (FRTR)'
# ...Cell[43][2] has content ''
# ...Cell[43][3] has content ''
# ...Cell[44][2] has content ''
# ...Cell[44][3] has content ''
# ...Cell[45][0] has content 'Germany'
# ...Cell[45][1] has content 'German Treasury Bill'
# ...Cell[45][2] has content '13 business days <= 1yr'
# ...Cell[45][3] has content '0.88%'
# ...Cell[46][1] has content '(BUBILL)'
# ...Cell[46][2] has content '>1yr <= 3yrs'
# ...Cell[46][3] has content '0.89%'
# ...Cell[47][1] has content 'Bundesschatzanweisungen'
# ...Cell[47][2] has content '>3yrs <= 7 yrs'
# ...Cell[47][3] has content '2.77%'
# ...Cell[48][1] has content '(BKO)'
# ...Cell[48][2] has content '>7yrs <= 13yrs'
# ...Cell[48][3] has content '3.85%'
# ...Cell[49][1] has content 'Bundesobligationen (OBL)'
# ...Cell[49][2] has content '> 12yrs <= 45yrs'
# ...Cell[49][3] has content '10.88%'
# ...Cell[50][1] has content 'Bundesobligationen I/L'
# ...Cell[50][2] has content '> 45yrs <= 65yrs'
# ...Cell[50][3] has content '19.77%'
# Table # 1 has 6 rows and 4 columns
# ...Cell[0][0] has content ''
# ...Cell[0][1] has content '(OBLI) Deutsche Bundesrepublik (DBR) Deutschland I/L (DBRI)'
# ...Cell[0][2] has content ''
# ...Cell[0][3] has content ''
# ...Cell[1][0] has content 'Italy'
# ...Cell[1][1] has content 'Buoni Ordinari del Tesoro (BOTS) Buoni del Tesoro Poliennali (BTPS) Buoni del Tesoro Poliennali I/L (BTPS) Certificati di Credito del Tesoro (CCTS) Italy International Bond (ITALY)'
# ...Cell[1][2] has content '13 business days <= 1yr > 1yr <= 3yrs >3yrs <= 7 yrs > 7yrs <= 13yrs >13yrs <= 45yrs > 45yrs <= 65yrs'
# ...Cell[1][3] has content '2.95% 6.35%'
# ...Cell[2][3] has content '9.44% 11.54%'
# ...Cell[3][3] has content '15.78% 28.55%'
# ...Cell[4][0] has content 'Japan'
# ...Cell[4][1] has content 'Japanese Treasury Bill (JGTB) Japanese Treasury Discount Bill (JTDB) Japanese Government Bond (JGB)'
# ...Cell[4][2] has content '17 business days <= 1yr >1yr <= 3yrs >3yrs <= 7 yrs >7yrs <= 13yrs >13yrs <= 45yrs > 45yrs <= 65yrs'
# ...Cell[4][3] has content '5.54% 7.78% 9.99% 13.98% 16.87% 27.88%'
# ...Cell[5][0] has content ''
# ...Cell[5][1] has content 'None'
# ...Cell[5][2] has content 'None'
# ...Cell[5][3] has content 'None'
# Table # 2 has 31 rows and 4 columns
# ...Cell[0][0] has content 'Government Securities (Description &'
# ...Cell[0][1] has content 'None'
# ...Cell[0][2] has content 'Term'
# ...Cell[0][3] has content 'Haircut (Conventional Bonds)'
# ...Cell[1][0] has content 'Bloomberg Code)'
# ...Cell[1][1] has content ''
# ...Cell[1][2] has content ''
# ...Cell[1][3] has content ''
# ...Cell[2][3] has content ''
# ...Cell[3][0] has content 'Luxembourg'
# ...Cell[3][1] has content 'Luxembougois Government'
# ...Cell[3][2] has content '45 business days <= 1yr'
# ...Cell[3][3] has content '0.79%'
# ...Cell[4][1] has content 'Bonds (LGB)'
# ...Cell[4][2] has content '>1yr <= 3yrs'
# ...Cell[4][3] has content '2.55%'
# ...Cell[5][1] has content ''
# ...Cell[5][2] has content '>3yrs <= 7 yrs'
# ...Cell[5][3] has content '4.78%'
# ...Cell[6][1] has content ''
# ...Cell[6][2] has content '>7yrs <= 13yrs'
# ...Cell[6][3] has content '5.98%'
# ...Cell[7][1] has content ''
# ...Cell[7][2] has content '>13yrs <= 45yrs'
# ...Cell[7][3] has content '6.55%'
# ...Cell[8][1] has content ''
# ...Cell[8][2] has content '> 45yrs <= 65yrs'
# ...Cell[8][3] has content '8.44%'
# ...Cell[9][0] has content 'Netherlands'
# ...Cell[9][1] has content 'Dutch Treasury Certificate'
# ...Cell[9][2] has content '49 business days <= 1yr'
# ...Cell[9][3] has content '0.78%'
# ...Cell[10][1] has content '(DTB)'
# ...Cell[10][2] has content '>1yr <= 3yrs'
# ...Cell[10][3] has content '0.95%'
# ...Cell[11][1] has content 'Dutch Government Bond'
# ...Cell[11][2] has content '>3yrs <= 7 yrs'
# ...Cell[11][3] has content '2.65%'
# ...Cell[12][1] has content '(NETHER)'
# ...Cell[12][2] has content '>7yrs <= 13yrs'
# ...Cell[12][3] has content '3.48%'
# ...Cell[13][1] has content ''
# ...Cell[13][2] has content '>13yrs <= 45yrs'
# ...Cell[13][3] has content '4.98%'
# ...Cell[14][1] has content ''
# ...Cell[14][2] has content '> 45yrs <= 65yrs'
# ...Cell[14][3] has content '7.63%'
# ...Cell[15][0] has content 'Norway'
# ...Cell[15][1] has content 'Norwegian Treasury Bill (NGTB)'
# ...Cell[15][2] has content '29 business days <= 1yr'
# ...Cell[15][3] has content '0.47%'
# ...Cell[16][2] has content '> 1yr <= 3yrs'
# ...Cell[16][3] has content '3.45%'
# ...Cell[17][1] has content 'Norwegian Government'
# ...Cell[17][2] has content '>3yrs <= 7 yrs'
# ...Cell[17][3] has content '4.25%'
# ...Cell[18][1] has content 'Bond (NGB)'
# ...Cell[18][2] has content '>7yrs <= 13yrs'
# ...Cell[18][3] has content 'NA'
# ...Cell[19][1] has content ''
# ...Cell[19][2] has content '>13yrs <= 45yrs'
# ...Cell[19][3] has content 'NA'
# ...Cell[20][1] has content ''
# ...Cell[20][2] has content '> 45yrs <= 65yrs'
# ...Cell[20][3] has content 'NA'
# ...Cell[21][0] has content 'Singapore'
# ...Cell[21][1] has content 'Singapore Treasury Bill'
# ...Cell[21][2] has content '35 business days <= 1yr'
# ...Cell[21][3] has content '2.70%'
# ...Cell[22][1] has content '(SITB)'
# ...Cell[22][2] has content '>1yr <= 3yrs'
# ...Cell[22][3] has content '3.25%'
# ...Cell[23][1] has content 'Singapore Government'
# ...Cell[23][2] has content '>3yrs <= 7 yrs'
# ...Cell[23][3] has content '4.78%'
# ...Cell[24][1] has content 'Bonds (SIGB)'
# ...Cell[24][2] has content '>7yrs <= 13yrs'
# ...Cell[24][3] has content '5.66%'
# ...Cell[25][1] has content 'Monetary Authority of'
# ...Cell[25][2] has content '>13yrs <= 45yrs'
# ...Cell[25][3] has content '16.50%'
# ...Cell[26][1] has content 'Singapore Bill (MASPSP)'
# ...Cell[26][2] has content '> 45yrs <= 65yrs'
# ...Cell[26][3] has content 'NA'
# ...Cell[27][0] has content 'Spain'
# ...Cell[27][1] has content 'Spanish Letras del Tesoro'
# ...Cell[27][2] has content '37 business days <= 1yr'
# ...Cell[27][3] has content '1.63%'
# ...Cell[28][1] has content '(SGLT)'
# ...Cell[28][2] has content '>1yr <= 3yrs'
# ...Cell[28][3] has content '5.13%'
# ...Cell[29][1] has content 'Spanish Government Bond'
# ...Cell[29][2] has content '>3yrs <= 7 yrs'
# ...Cell[29][3] has content '6.13%'
# ...Cell[30][1] has content '(SPGB)'
# ...Cell[30][2] has content '>7yrs <= 13yrs'
# ...Cell[30][3] has content '15.38%'
# Table # 3 has 48 rows and 4 columns
# ...Cell[0][0] has content ''
# ...Cell[0][1] has content ''
# ...Cell[0][2] has content '\> 13yrs <= 45yrs > 45yrs <= 65yrs'
# ...Cell[0][3] has content '19.25% 25.75%'
# ...Cell[1][0] has content 'Sweden'
# ...Cell[1][1] has content 'Swedish Treasury Bill'
# ...Cell[1][2] has content '64 business days <= 1yr'
# ...Cell[1][3] has content '0.98%'
# ...Cell[2][1] has content '(SWTB)'
# ...Cell[2][2] has content '>1yr <= 3yrs'
# ...Cell[2][3] has content '1.48%'
# ...Cell[3][1] has content 'Swedish Government Bond'
# ...Cell[3][2] has content '>3yrs <= 7 yrs'
# ...Cell[3][3] has content '2.57%'
# ...Cell[4][1] has content '(SGB)'
# ...Cell[4][2] has content '>7yrs <= 13yrs'
# ...Cell[4][3] has content '3.98%'
# ...Cell[5][1] has content 'Swedish Government I/L'
# ...Cell[5][2] has content '>13yrs <= 45yrs'
# ...Cell[5][3] has content 'NA'
# ...Cell[6][1] has content '(SGBI)'
# ...Cell[6][2] has content '> 45yrs <= 65yrs'
# ...Cell[6][3] has content 'NA'
# ...Cell[7][1] has content 'Sweden International Bond (SWED)'
# ...Cell[7][2] has content ''
# ...Cell[7][3] has content ''
# ...Cell[8][2] has content ''
# ...Cell[8][3] has content ''
# ...Cell[9][0] has content 'Switzerland'
# ...Cell[9][1] has content 'Swiss Treasury Bill (SWISTB)'
# ...Cell[9][2] has content '37 business days <= 1yr'
# ...Cell[9][3] has content '0.78%'
# ...Cell[10][2] has content '>1yr <= 3yrs'
# ...Cell[10][3] has content '0.87%'
# ...Cell[11][1] has content 'Swiss Government Bond'
# ...Cell[11][2] has content '>3yrs <= 7 yrs'
# ...Cell[11][3] has content '2.73%'
# ...Cell[12][1] has content '(SWISS)'
# ...Cell[12][2] has content '>7yrs <= 13yrs'
# ...Cell[12][3] has content '2.90%'
# ...Cell[13][1] has content ''
# ...Cell[13][2] has content '>13yrs <= 45yrs'
# ...Cell[13][3] has content '3.59%'
# ...Cell[14][2] has content ''
# ...Cell[14][3] has content '16.37%'
# ...Cell[15][0] has content 'None'
# ...Cell[15][1] has content 'None'
# ...Cell[15][2] has content '> 45yrs <= 65yrs'
# ...Cell[15][3] has content 'None'
# ...Cell[16][0] has content 'United Kingdom'
# ...Cell[16][1] has content 'United Kingdom Treasury'
# ...Cell[16][2] has content '90 business days <= 1yr'
# ...Cell[16][3] has content '0.25%'
# ...Cell[17][1] has content 'Bill (UKTB)'
# ...Cell[17][2] has content '>1yr <= 3yrs'
# ...Cell[17][3] has content '1.30%'
# ...Cell[18][1] has content 'United Kingdom Gilt (UKT)'
# ...Cell[18][2] has content '>3yrs <= 7 yrs'
# ...Cell[18][3] has content '2.30%'
# ...Cell[19][1] has content 'United Kingdom Index'
# ...Cell[19][2] has content '>7yrs <= 13yrs'
# ...Cell[19][3] has content '3.50%'
# ...Cell[20][1] has content 'Linked Gilt (UKTI)'
# ...Cell[20][2] has content '>13yrs <= 45yrs'
# ...Cell[20][3] has content '10.50%'
# ...Cell[21][2] has content '> 45yrs'
# ...Cell[21][3] has content '16.63%'
# ...Cell[22][0] has content 'United States'
# ...Cell[22][1] has content 'United States Treasury Bill (B)'
# ...Cell[22][2] has content '13 business days <= 1yr >1yr <= 3yrs'
# ...Cell[22][3] has content '0.78%'
# ...Cell[23][3] has content '1.75%'
# ...Cell[24][1] has content 'United States Cash'
# ...Cell[24][2] has content '>3yrs <= 7 yrs'
# ...Cell[24][3] has content '2.98%'
# ...Cell[25][1] has content 'Management Bill (CMB)'
# ...Cell[25][2] has content '>7yrs <= 13yrs'
# ...Cell[25][3] has content '3.88%'
# ...Cell[26][1] has content 'United States Treasury'
# ...Cell[26][2] has content '>13yrs <= 45yrs'
# ...Cell[26][3] has content '8.78%'
# ...Cell[27][1] has content 'Bond (T)'
# ...Cell[27][2] has content '> 45yrs <= 65yrs'
# ...Cell[27][3] has content 'NA'
# ...Cell[28][1] has content 'United States Treasury Inflation Indexed Bond (TII) United States Treasury Floating Rate Note (TF)'
# ...Cell[28][2] has content ''
# ...Cell[28][3] has content ''
# ...Cell[29][0] has content ''
# ...Cell[29][1] has content 'None'
# ...Cell[29][2] has content 'None'
# ...Cell[29][3] has content 'None'
# ...Cell[30][0] has content 'Government & Regional Agencies (Description & Bloomberg Code)'
# ...Cell[30][1] has content 'None'
# ...Cell[30][2] has content 'Term'
# ...Cell[30][3] has content 'Haircut'
# ...Cell[31][2] has content ''
# ...Cell[31][3] has content '(Conventional'
# ...Cell[32][2] has content ''
# ...Cell[32][3] has content 'Bonds)'
# ...Cell[33][3] has content ''
# ...Cell[34][0] has content 'UK Agencies'
# ...Cell[34][1] has content 'Network Rail Infrastructure Finance Plc (UKRAIL)'
# ...Cell[34][2] has content '69 business days <= 1yr'
# ...Cell[34][3] has content '0.44%'
# ...Cell[35][2] has content '>1yr <= 3yrs'
# ...Cell[35][3] has content '2.59%'
# ...Cell[36][2] has content '> 3yrs <= 7 yrs'
# ...Cell[36][3] has content '3.00%'
# ...Cell[37][2] has content '>7yrs <= 13yrs'
# ...Cell[37][3] has content '4.50%'
# ...Cell[38][2] has content '>13yrs <= 45yrs'
# ...Cell[38][3] has content '12.80%'
# ...Cell[39][2] has content '> 45yrs <= 65yrs'
# ...Cell[39][3] has content 'NA'
# ...Cell[40][0] has content 'EUR Agencies'
# ...Cell[40][1] has content 'Kreditanstalt für Wiederaufbau (KFW)'
# ...Cell[40][2] has content '73 business days <= 1yr'
# ...Cell[40][3] has content '0.76%'
# ...Cell[41][2] has content '>1yr <= 3yrs'
# ...Cell[41][3] has content '1.34%'
# ...Cell[42][1] has content 'FMS Wertmanagement (FMSWER)'
# ...Cell[42][2] has content '>3yrs <= 7 yrs'
# ...Cell[42][3] has content '11.77%'
# ...Cell[43][2] has content '>7yrs <= 13yrs'
# ...Cell[43][3] has content '13.45%'
# ...Cell[44][2] has content '>13yrs <= 45yrs'
# ...Cell[44][3] has content '19.48%'
# ...Cell[45][2] has content '> 45yrs <= 65yrs'
# ...Cell[45][3] has content 'NA'
# ...Cell[46][0] has content 'EUR Agencies'
# ...Cell[46][1] has content 'Rentenbank (RENTEN)'
# ...Cell[46][2] has content '82 business days <= 1yr'
# ...Cell[46][3] has content '8.53%'
# ...Cell[47][2] has content '>1yr <= 3yrs'
# ...Cell[47][3] has content '12.35%'
# Table # 4 has 42 rows and 4 columns
# ...Cell[0][0] has content ''
# ...Cell[0][1] has content ''
# ...Cell[0][2] has content '\>3yrs <= 7 yrs'
# ...Cell[0][3] has content '13.50%'
# ...Cell[1][2] has content '>7yrs <= 13yrs'
# ...Cell[1][3] has content 'NA'
# ...Cell[2][2] has content '>13yrs <= 45yrs'
# ...Cell[2][3] has content 'NA'
# ...Cell[3][2] has content '> 45yrs <= 65yrs'
# ...Cell[3][3] has content 'NA'
# ...Cell[4][0] has content 'EUR Agencies'
# ...Cell[4][1] has content 'Caisse d'Amortissement de la Dette Sociale (CADES)'
# ...Cell[4][2] has content '91 business days <= 1yr'
# ...Cell[4][3] has content '0.64% 2.89%'
# ...Cell[5][2] has content '>1yr <= 3yrs'
# ...Cell[6][2] has content '>3yrs <= 7 yrs'
# ...Cell[6][3] has content '4.55%'
# ...Cell[7][2] has content '>7yrs <= 13yrs'
# ...Cell[7][3] has content 'NA'
# ...Cell[8][2] has content '>13yrs <= 45yrs'
# ...Cell[8][3] has content 'NA'
# ...Cell[9][2] has content '> 45yrs <= 65yrs'
# ...Cell[9][3] has content 'NA'
# ...Cell[10][0] has content 'US Agencies'
# ...Cell[10][1] has content 'Federal National Mortgage Association (FNMA) Federal Home Loan'
# ...Cell[10][2] has content '43 business days <= 1yr'
# ...Cell[10][3] has content '0.78%'
# ...Cell[11][2] has content '>1yr <= 3yrs'
# ...Cell[11][3] has content '1.44%'
# ...Cell[12][2] has content '>3yrs <= 7 yrs'
# ...Cell[12][3] has content '3.88%'
# ...Cell[13][1] has content 'Mortgage Corporation (FHLMC)'
# ...Cell[13][2] has content '>7yrs <= 13yrs'
# ...Cell[13][3] has content '4.55%'
# ...Cell[14][2] has content '>13yrs <= 45yrs'
# ...Cell[14][3] has content 'NA'
# ...Cell[15][1] has content 'Federal Home Loan Banks (FHLB)'
# ...Cell[15][2] has content '> 45yrs <= 65yrs'
# ...Cell[15][3] has content 'NA'
# ...Cell[16][0] has content 'REG Agencies'
# ...Cell[16][1] has content 'Kommuninvest I Sverige (KOMINS)'
# ...Cell[16][2] has content '36 business days <= 1yr >1yr <= 3yrs'
# ...Cell[16][3] has content '15.00% 16.00% 17.00%'
# ...Cell[17][2] has content '>3yrs <= 7 yrs'
# ...Cell[18][2] has content '>7yrs <= 13yrs'
# ...Cell[18][3] has content '18.00%'
# ...Cell[19][2] has content '>13yrs <= 45yrs'
# ...Cell[19][3] has content '19.00%'
# ...Cell[20][2] has content '> 45yrs <= 65yrs'
# ...Cell[20][3] has content 'NA'
# ...Cell[21][0] has content ''
# ...Cell[21][1] has content 'None'
# ...Cell[21][2] has content ''
# ...Cell[21][3] has content 'None'
# ...Cell[22][0] has content 'Mortgage Backed Securities (Description & Bloomberg Code)'
# ...Cell[22][1] has content 'None'
# ...Cell[22][2] has content 'Term Since Issue'
# ...Cell[22][3] has content 'Haircut (Conventional Bonds)'
# ...Cell[23][0] has content 'US MBS'
# ...Cell[23][1] has content 'General National Mortgage Association (G2)'
# ...Cell[23][2] has content 'New (0 - 30 months) Medium (30- 60 months)'
# ...Cell[23][3] has content '22.00% 24.50%'
# ...Cell[24][2] has content 'Seasoned (> 60 months)'
# ...Cell[24][3] has content 'NA'
# ...Cell[25][0] has content ''
# ...Cell[25][1] has content 'None'
# ...Cell[25][2] has content 'None'
# ...Cell[25][3] has content ''
# ...Cell[26][0] has content 'Supranationals (Description & Bloomberg Code)'
# ...Cell[26][1] has content 'None'
# ...Cell[26][2] has content 'Term'
# ...Cell[26][3] has content 'Haircut (Conventional Bonds)'
# ...Cell[27][0] has content 'Supranationals'
# ...Cell[27][1] has content 'International Bank for Reconstruction & Development (IBRD)'
# ...Cell[27][2] has content '42 business days <= 1yr'
# ...Cell[27][3] has content '1.25%'
# ...Cell[28][2] has content '>1yr <= 3yrs'
# ...Cell[28][3] has content '2.25%'
# ...Cell[29][2] has content '>3yrs <= 7 yrs'
# ...Cell[29][3] has content '4.35%'
# ...Cell[30][2] has content '>7yrs <= 13yrs'
# ...Cell[30][3] has content '8.88%'
# ...Cell[31][2] has content '>13yrs <= 45yrs'
# ...Cell[31][3] has content 'NA'
# ...Cell[32][2] has content '> 45yrs <= 65yrs'
# ...Cell[32][3] has content 'NA'
# ...Cell[33][0] has content 'Supranationals'
# ...Cell[33][1] has content 'European Investment Bank (EIB)'
# ...Cell[33][2] has content '99 business days <= 1yr >1yr <= 3yrs'
# ...Cell[33][3] has content '2.75% 4.00%'
# ...Cell[34][2] has content '>3yrs <= 7 yrs'
# ...Cell[34][3] has content '6.75%'
# ...Cell[35][2] has content '>7yrs <= 13yrs'
# ...Cell[35][3] has content '13.50%'
# ...Cell[36][2] has content '>13yrs <= 45yrs'
# ...Cell[36][3] has content '18.75%'
# ...Cell[37][2] has content '> 45yrs <= 65yrs'
# ...Cell[37][3] has content 'NA'
# ...Cell[38][0] has content 'Supranationals'
# ...Cell[38][1] has content 'European Stability Facility Mechanism (EFSF) European Stability Mechanism (ESM)'
# ...Cell[38][2] has content '63 business days <= 1yr >1yr <= 3yrs'
# ...Cell[38][3] has content '10.50% 12.00%'
# ...Cell[39][2] has content '>3yrs <= 7 yrs'
# ...Cell[39][3] has content '13.50%'
# ...Cell[40][2] has content '>7yrs <= 13yrs'
# ...Cell[40][3] has content '16.50%'
# ...Cell[41][1] has content 'European Stability'
# ...Cell[41][2] has content '>13yrs <= 45yrs'
# ...Cell[41][3] has content 'NA'
# Table # 5 has 14 rows and 4 columns
# ...Cell[0][0] has content ''
# ...Cell[0][1] has content 'Mechanism T Bills (ESMTB)'
# ...Cell[0][2] has content '> 45yrs <= 65yrs'
# ...Cell[0][3] has content 'NA'
# ...Cell[1][0] has content 'Supranationals'
# ...Cell[1][1] has content 'European Bank for'
# ...Cell[1][2] has content '27 business days <= 1yr'
# ...Cell[1][3] has content '0.75%'
# ...Cell[2][1] has content 'Reconstruction &'
# ...Cell[2][2] has content '>1yr <= 3yrs'
# ...Cell[2][3] has content 'NA'
# ...Cell[3][1] has content 'Development (EBRD)'
# ...Cell[3][2] has content '>3yrs <= 7 yrs'
# ...Cell[3][3] has content 'NA'
# ...Cell[4][2] has content '>7yrs <= 13yrs'
# ...Cell[4][3] has content 'NA'
# ...Cell[5][1] has content ''
# ...Cell[5][2] has content '>13yrs <= 45yrs'
# ...Cell[5][3] has content 'NA'
# ...Cell[6][2] has content '> 45yrs <= 65yrs'
# ...Cell[6][3] has content ''
# ...Cell[7][0] has content 'Supranationals'
# ...Cell[7][1] has content 'European Union (EU) European Union T Bills'
# ...Cell[7][2] has content '32 business days <= 1yr'
# ...Cell[7][3] has content '0.75%'
# ...Cell[8][2] has content '>1yr <= 3yrs'
# ...Cell[8][3] has content '1.50%'
# ...Cell[9][1] has content '(EUB)'
# ...Cell[9][2] has content '>3yrs <= 7 yrs'
# ...Cell[9][3] has content '2.50%'
# ...Cell[10][2] has content '>7yrs <= 13yrs'
# ...Cell[10][3] has content '3.50%'
# ...Cell[11][1] has content ''
# ...Cell[11][2] has content '> 13yrs <= 45yrs'
# ...Cell[11][3] has content '18.50%'
# ...Cell[12][1] has content ''
# ...Cell[12][2] has content '> 45yrs <= 65yrs'
# ...Cell[12][3] has content '45.89%'
# ...Cell[13][0] has content ''
# ...Cell[13][1] has content 'None'
# ...Cell[13][2] has content 'None'
# ...Cell[13][3] has content ''

# %% [markdown]
# Print Raw Markdown

# %%
print(resp["content"])
# Out:
# | Country | Government Securities (Description & Bloomberg Code) | Term | Haircut (Conventional Bonds) |
# | - | - | - | - |
# | Australia | Australian Treasury Bill | 5 business days <= 2yr | 0.78% |
# || (ACTB) | > 2yr <= 5yrs | 1.23% |
# || Australian Government Bond | > 5yrs <= 7 yrs | 2.50% |
# || (ACGB) | >7yrs <= 10yrs | 3.75% |
# || Australian Government I/L | >10yrs <= 40yrs | 9.25% |
# || (ACGB) | >40yrs <= 60yrs | 10.35% |
# | Austria | Austrian Treasury Bill | 18 business days <= 1yr | 0.45% |
# || (RATB) | >1yr <= 4yrs | 1.75% |
# || Austrian Government Bond | >4yrs <= 8 yrs | 2.85% |
# || (RAGB) | >8yrs <= 12yrs | 3.25% |
# || Austria International Bond (AUST)
# ||| || || |
# | Belgium | Belgian Treasury Bill (BGTB) | 6 business days <= 1yr | 0.89% |
# || Belgian Government Bond | >1yr <= 2yrs | 1.96% |
# || (BGB) | > 2yrs <= 5 yrs | 3.65% |
# || | > 5yrs <= 8yrs | 5.68% |
# || | > 8yrs <= 17yrs | 8.00% |
# || | > 17yrs <= 55yrs | 13.75% |
# | Canada | Canadian Treasury Bill (CTB) | 15 calendar days <= 2yr | 0.97% |
# || Canadian Government Bond | > 2yr <= 5yrs | 1.37% |
# || (CAN) | > 5yrs <= 8yrs | 2.56% |
# || Canada Government Real | >8yrs <= 10yrs | 3.79% |
# || Return Bond (CAN) | > 10yrs <= 35yrs | 7.85% |
# | Denmark | Danish Treasury Bill (DGTB) | 8 business days <= 2yr | 0.58% |
# || Danish Government Bond | > 2yr <= 6yrs | 1.69% |
# || (DGB) | >6yrs <= 9yrs | 2.58% |
# || Danish Government I/L | >9yrs <= 13yrs | 2.73% |
# || (DGBI) | >13yrs <= 40yrs | 10.52% |
# || | > 40yrs <= 60yrs | 6.87% |
# | Finland | Finnish Treasury Bill (RFTB) | 6 business days <= 2yr | 0.38% |
# || Finnish Government Bonds | > 2yr <= 3yrs | 1.68% |
# || (RFGB) | >3yrs <= 7 yrs | 2.71% |
# || | >7yrs <= 12yrs | 3.62% |
# || | > 12yrs <= 45yrs | 10.86% |
# || | > 45yrs <= 65yrs | 13.98% |
# | France | Bons du Trésor à Taux Fixe et | 6 business days <= 2yr | 0.47% |
# || Intérêt Précompté (BTF) | >2yr <= 3yrs | 1.89% |
# || Bons du Trésor à Taux Fixe et | >3yrs <= 7 yrs | 3.55% |
# || Intérêt Annuel (BTNS) | > 7yrs <= 13yrs | 12.66% |
# || Bons du Trésor à Taux Fixe et | >13yrs <= 45yrs | 14.88% |
# || Intérêt Annuel I/L (BTNS) Obligations Assimilables du Trésor (FRTR) | > 45yrs <= 65yrs | 16.44% |
# |||
# || || Obligations Assimilables du Trésor I/L (FRTR)
# ||| | || | |
# | Germany | German Treasury Bill | 13 business days <= 1yr | 0.88% |
# || (BUBILL) | >1yr <= 3yrs | 0.89% |
# || Bundesschatzanweisungen | >3yrs <= 7 yrs | 2.77% |
# || (BKO) | >7yrs <= 13yrs | 3.85% |
# || Bundesobligationen (OBL) | > 12yrs <= 45yrs | 10.88% |
# || Bundesobligationen I/L | > 45yrs <= 65yrs | 19.77% |
#
# | | (OBLI) Deutsche Bundesrepublik (DBR) Deutschland I/L (DBRI) | | |
# | - | - | - | - |
# | Italy | Buoni Ordinari del Tesoro (BOTS) Buoni del Tesoro Poliennali (BTPS) Buoni del Tesoro Poliennali I/L (BTPS) Certificati di Credito del Tesoro (CCTS) Italy International Bond (ITALY) | 13 business days <= 1yr > 1yr <= 3yrs >3yrs <= 7 yrs > 7yrs <= 13yrs >13yrs <= 45yrs > 45yrs <= 65yrs | 2.95% 6.35% |
# |||| 9.44% 11.54% |
# |||| 15.78% 28.55% |
# | Japan | Japanese Treasury Bill (JGTB) Japanese Treasury Discount Bill (JTDB) Japanese Government Bond (JGB) | 17 business days <= 1yr >1yr <= 3yrs >3yrs <= 7 yrs >7yrs <= 13yrs >13yrs <= 45yrs > 45yrs <= 65yrs | 5.54% 7.78% 9.99% 13.98% 16.87% 27.88% |
# | | None | None | None |
#
# | Government Securities (Description & | None | Term | Haircut (Conventional Bonds) |
# | - | - | - | - |
# | Bloomberg Code)
# || || || || |
# | Luxembourg | Luxembougois Government | 45 business days <= 1yr | 0.79% |
# || Bonds (LGB) | >1yr <= 3yrs | 2.55% |
# || | >3yrs <= 7 yrs | 4.78% |
# || | >7yrs <= 13yrs | 5.98% |
# || | >13yrs <= 45yrs | 6.55% |
# || | > 45yrs <= 65yrs | 8.44% |
# | Netherlands | Dutch Treasury Certificate | 49 business days <= 1yr | 0.78% |
# || (DTB) | >1yr <= 3yrs | 0.95% |
# || Dutch Government Bond | >3yrs <= 7 yrs | 2.65% |
# || (NETHER) | >7yrs <= 13yrs | 3.48% |
# || | >13yrs <= 45yrs | 4.98% |
# || | > 45yrs <= 65yrs | 7.63% |
# | Norway | Norwegian Treasury Bill (NGTB) | 29 business days <= 1yr | 0.47% |
# ||| > 1yr <= 3yrs | 3.45% |
# || Norwegian Government | >3yrs <= 7 yrs | 4.25% |
# || Bond (NGB) | >7yrs <= 13yrs | NA |
# || | >13yrs <= 45yrs | NA |
# || | > 45yrs <= 65yrs | NA |
# | Singapore | Singapore Treasury Bill | 35 business days <= 1yr | 2.70% |
# || (SITB) | >1yr <= 3yrs | 3.25% |
# || Singapore Government | >3yrs <= 7 yrs | 4.78% |
# || Bonds (SIGB) | >7yrs <= 13yrs | 5.66% |
# || Monetary Authority of | >13yrs <= 45yrs | 16.50% |
# || Singapore Bill (MASPSP) | > 45yrs <= 65yrs | NA |
# | Spain | Spanish Letras del Tesoro | 37 business days <= 1yr | 1.63% |
# || (SGLT) | >1yr <= 3yrs | 5.13% |
# || Spanish Government Bond | >3yrs <= 7 yrs | 6.13% |
# || (SPGB) | >7yrs <= 13yrs | 15.38% |
#
# | | | \> 13yrs <= 45yrs > 45yrs <= 65yrs | 19.25% 25.75% |
# | - | - | - | - |
# | Sweden | Swedish Treasury Bill | 64 business days <= 1yr | 0.98% |
# || (SWTB) | >1yr <= 3yrs | 1.48% |
# || Swedish Government Bond | >3yrs <= 7 yrs | 2.57% |
# || (SGB) | >7yrs <= 13yrs | 3.98% |
# || Swedish Government I/L | >13yrs <= 45yrs | NA |
# || (SGBI) | > 45yrs <= 65yrs | NA |
# || Sweden International Bond (SWED)
# ||| | || | |
# | Switzerland | Swiss Treasury Bill (SWISTB) | 37 business days <= 1yr | 0.78% |
# ||| >1yr <= 3yrs | 0.87% |
# || Swiss Government Bond | >3yrs <= 7 yrs | 2.73% |
# || (SWISS) | >7yrs <= 13yrs | 2.90% |
# || | >13yrs <= 45yrs | 3.59% |
# ||| | 16.37% |
# | None | None | > 45yrs <= 65yrs | None |
# | United Kingdom | United Kingdom Treasury | 90 business days <= 1yr | 0.25% |
# || Bill (UKTB) | >1yr <= 3yrs | 1.30% |
# || United Kingdom Gilt (UKT) | >3yrs <= 7 yrs | 2.30% |
# || United Kingdom Index | >7yrs <= 13yrs | 3.50% |
# || Linked Gilt (UKTI) | >13yrs <= 45yrs | 10.50% |
# ||| > 45yrs | 16.63% |
# | United States | United States Treasury Bill (B) | 13 business days <= 1yr >1yr <= 3yrs | 0.78% |
# |||| 1.75% |
# || United States Cash | >3yrs <= 7 yrs | 2.98% |
# || Management Bill (CMB) | >7yrs <= 13yrs | 3.88% |
# || United States Treasury | >13yrs <= 45yrs | 8.78% |
# || Bond (T) | > 45yrs <= 65yrs | NA |
# || United States Treasury Inflation Indexed Bond (TII) United States Treasury Floating Rate Note (TF) | | |
# | | None | None | None |
# | Government & Regional Agencies (Description & Bloomberg Code) | None | Term | Haircut |
# ||| | (Conventional |
# ||| | Bonds) |
# |||| |
# | UK Agencies | Network Rail Infrastructure Finance Plc (UKRAIL) | 69 business days <= 1yr | 0.44% |
# ||| >1yr <= 3yrs | 2.59% |
# ||| > 3yrs <= 7 yrs | 3.00% |
# ||| >7yrs <= 13yrs | 4.50% |
# ||| >13yrs <= 45yrs | 12.80% |
# ||| > 45yrs <= 65yrs | NA |
# | EUR Agencies | Kreditanstalt für Wiederaufbau (KFW) | 73 business days <= 1yr | 0.76% |
# ||| >1yr <= 3yrs | 1.34% |
# || FMS Wertmanagement (FMSWER) | >3yrs <= 7 yrs | 11.77% |
# ||| >7yrs <= 13yrs | 13.45% |
# ||| >13yrs <= 45yrs | 19.48% |
# ||| > 45yrs <= 65yrs | NA |
# | EUR Agencies | Rentenbank (RENTEN) | 82 business days <= 1yr | 8.53% |
# ||| >1yr <= 3yrs | 12.35% |
#
# |||||
# | - | - | - | - |
# | | | \>3yrs <= 7 yrs | 13.50% |
# ||| >7yrs <= 13yrs | NA |
# ||| >13yrs <= 45yrs | NA |
# ||| > 45yrs <= 65yrs | NA |
# | EUR Agencies | Caisse d'Amortissement de la Dette Sociale (CADES) | 91 business days <= 1yr | 0.64% 2.89% |
# ||| >1yr <= 3yrs ||
# ||| >3yrs <= 7 yrs | 4.55% |
# ||| >7yrs <= 13yrs | NA |
# ||| >13yrs <= 45yrs | NA |
# ||| > 45yrs <= 65yrs | NA |
# | US Agencies | Federal National Mortgage Association (FNMA) Federal Home Loan | 43 business days <= 1yr | 0.78% |
# ||| >1yr <= 3yrs | 1.44% |
# ||| >3yrs <= 7 yrs | 3.88% |
# || Mortgage Corporation (FHLMC) | >7yrs <= 13yrs | 4.55% |
# ||| >13yrs <= 45yrs | NA |
# || Federal Home Loan Banks (FHLB) | > 45yrs <= 65yrs | NA |
# | REG Agencies | Kommuninvest I Sverige (KOMINS) | 36 business days <= 1yr >1yr <= 3yrs | 15.00% 16.00% 17.00% |
# ||| >3yrs <= 7 yrs ||
# ||| >7yrs <= 13yrs | 18.00% |
# ||| >13yrs <= 45yrs | 19.00% |
# ||| > 45yrs <= 65yrs | NA |
# | | None | | None |
# | Mortgage Backed Securities (Description & Bloomberg Code) | None | Term Since Issue | Haircut (Conventional Bonds) |
# | US MBS | General National Mortgage Association (G2) | New (0 - 30 months) Medium (30- 60 months) | 22.00% 24.50% |
# ||| Seasoned (> 60 months) | NA |
# | | None | None | |
# | Supranationals (Description & Bloomberg Code) | None | Term | Haircut (Conventional Bonds) |
# | Supranationals | International Bank for Reconstruction & Development (IBRD) | 42 business days <= 1yr | 1.25% |
# ||| >1yr <= 3yrs | 2.25% |
# ||| >3yrs <= 7 yrs | 4.35% |
# ||| >7yrs <= 13yrs | 8.88% |
# ||| >13yrs <= 45yrs | NA |
# ||| > 45yrs <= 65yrs | NA |
# | Supranationals | European Investment Bank (EIB) | 99 business days <= 1yr >1yr <= 3yrs | 2.75% 4.00% |
# ||| >3yrs <= 7 yrs | 6.75% |
# ||| >7yrs <= 13yrs | 13.50% |
# ||| >13yrs <= 45yrs | 18.75% |
# ||| > 45yrs <= 65yrs | NA |
# | Supranationals | European Stability Facility Mechanism (EFSF) European Stability Mechanism (ESM) | 63 business days <= 1yr >1yr <= 3yrs | 10.50% 12.00% |
# ||| >3yrs <= 7 yrs | 13.50% |
# ||| >7yrs <= 13yrs | 16.50% |
# || European Stability | >13yrs <= 45yrs | NA |
#
# | | Mechanism T Bills (ESMTB) | > 45yrs <= 65yrs | NA |
# | - | - | - | - |
# | Supranationals | European Bank for | 27 business days <= 1yr | 0.75% |
# || Reconstruction & | >1yr <= 3yrs | NA |
# || Development (EBRD) | >3yrs <= 7 yrs | NA |
# ||| >7yrs <= 13yrs | NA |
# || | >13yrs <= 45yrs | NA |
# ||| > 45yrs <= 65yrs | |
# | Supranationals | European Union (EU) European Union T Bills | 32 business days <= 1yr | 0.75% |
# ||| >1yr <= 3yrs | 1.50% |
# || (EUB) | >3yrs <= 7 yrs | 2.50% |
# ||| >7yrs <= 13yrs | 3.50% |
# || | > 13yrs <= 45yrs | 18.50% |
# || | > 45yrs <= 65yrs | 45.89% |
# | | None | None | |

# %% [markdown]
# Use Structued Outputs with Azure OpenAI. Define the class basemodel and properties (ex: asset name, party type, tenure max and min years)

# %%
from typing import Optional
from pydantic import BaseModel

# %%
class Collateral(BaseModel):
    name: Optional[str]
    tenure_min: Optional[str]
    tenure_max: Optional[str]
    haircut_percentage: Optional[str]

class Invoice(BaseModel):
    collaterals: Optional[list[Collateral]]

# %%
if resp["tables"]:
    completion = client.beta.chat.completions.parse(
    model="gpt-4o",
    messages=[
        {
            "role": "system",
            "content": """You are an AI assistant that specializes in extracting collateral information from a single, large table that spans multiple pages. 
            The table contains Government Securities from multiple countries along with different Maturity levels and Haircut values. Each page is a continuation of the previous one, and all must be combined into a **single unified table**. 
            
            ### Extraction Instructions: 
            1. **Multi-Page Table Handling**: \ 
            - Ensure **all pages are processed** together as part of the same table. 
            - **Do not stop after the first page**—continue extracting all consecutive pages. 
            
            2. **Columns to Extract**:
            Combine the collateral Table with different countries' Government Securities and different Maturity levels spans multiple pages, all of which must be extracted for each asset value. Make sure you get all the consecutive pages from australia to italy to luxembourg to UK agencies etc, as every page is part of the one table. 
            - **Government Securities (Asset Type)**: Extract into multiple rows if different asset types are present. Extract as many asset types that are present. 
            - **Tenure Min Maturity** is part of the Term column. Anything on the LEFT side of the sign (<) OR more than sign (>), is the value WITH the sign. Example: 2yr <= Maturity <= 5 yrs would return '2yr <='. Another example: 5yrs <= Maturity < 7 yrs would return '5yrs <='. Note that the values can repeat. 
            - **Tenure Max Maturity**: is part of the Term column. Anything on the RIGHT side of the less than sign (<), is the value AND the sign. Example: Maturity < 9M would return '< 9M'. 2.5Y < Maturity <= 5.5Y would return '<= 5.5Y'. Note that the values can repeat. 
            - **The Haircut Percentage**: is in its own column. 

            3. **Data Structuring**:
            - **Extract each government security as a separate row** if multiple asset types are listed.
            - If a country has multiple securities, **list them individually** rather than merging.
            - Ensure the **tenure values are consistently extracted**, repeating where necessary.

            Make sure the extraction continues through **all countries, from Australia to Italy to Luxembourg to UK agencies, etc.**, ensuring that the entire dataset is fully included in the output."""
        },

        {
            "role": "user",
            "content": resp["content"],
        }
    ],
    response_format=Invoice,
    max_tokens=16384,
    temperature=0.1,
    top_p=0.1
)

# %%
#event = completion.choices[0].message.parsed
#print(event.model_dump_json(indent=2))

print("Total token usage: ")
print(completion.usage)
# Out:
# Total token usage:
# CompletionUsage(completion_tokens=5408, prompt_tokens=4490, total_tokens=9898, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))

# %%
event = completion.choices[0].message.parsed

print(event.model_dump_json(indent=2))
# Out:
# {
#   "collaterals": [
#     {
#       "name": "Australian Treasury Bill",
#       "tenure_min": "5 business days <=",
#       "tenure_max": "<= 2yr",
#       "haircut_percentage": "0.78%"
#     },
#     {
#       "name": "Australian Treasury Bill",
#       "tenure_min": "> 2yr <=",
#       "tenure_max": "<= 5yrs",
#       "haircut_percentage": "1.23%"
#     },
#     {
#       "name": "Australian Government Bond",
#       "tenure_min": "> 5yrs <=",
#       "tenure_max": "<= 7 yrs",
#       "haircut_percentage": "2.50%"
#     },
#     {
#       "name": "Australian Government Bond",
#       "tenure_min": ">7yrs <=",
#       "tenure_max": "<= 10yrs",
#       "haircut_percentage": "3.75%"
#     },
#     {
#       "name": "Australian Government I/L",
#       "tenure_min": ">10yrs <=",
#       "tenure_max": "<= 40yrs",
#       "haircut_percentage": "9.25%"
#     },
#     {
#       "name": "Australian Government I/L",
#       "tenure_min": ">40yrs <=",
#       "tenure_max": "<= 60yrs",
#       "haircut_percentage": "10.35%"
#     },
#     {
#       "name": "Austrian Treasury Bill",
#       "tenure_min": "18 business days <=",
#       "tenure_max": "<= 1yr",
#       "haircut_percentage": "0.45%"
#     },
#     {
#       "name": "Austrian Treasury Bill",
#       "tenure_min": ">1yr <=",
#       "tenure_max": "<= 4yrs",
#       "haircut_percentage": "1.75%"
#     },
#     {
#       "name": "Austrian Government Bond",
#       "tenure_min": ">4yrs <=",
#       "tenure_max": "<= 8 yrs",
#       "haircut_percentage": "2.85%"
#     },
#     {
#       "name": "Austrian Government Bond",
#       "tenure_min": ">8yrs <=",
#       "tenure_max": "<= 12yrs",
#       "haircut_percentage": "3.25%"
#     },
#     {
#       "name": "Belgian Treasury Bill",
#       "tenure_min": "6 business days <=",
#       "tenure_max": "<= 1yr",
#       "haircut_percentage": "0.89%"
#     },
#     {
#       "name": "Belgian Government Bond",
#       "tenure_min": ">1yr <=",
#       "tenure_max": "<= 2yrs",
#       "haircut_percentage": "1.96%"
#     },
#     {
#       "name": "Belgian Government Bond",
#       "tenure_min": "> 2yrs <=",
#       "tenure_max": "<= 5 yrs",
#       "haircut_percentage": "3.65%"
#     },
#     {
#       "name": "Belgian Government Bond",
#       "tenure_min": "> 5yrs <=",
#       "tenure_max": "<= 8yrs",
#       "haircut_percentage": "5.68%"
#     },
#     {
#       "name": "Belgian Government Bond",
#       "tenure_min": "> 8yrs <=",
#       "tenure_max": "<= 17yrs",
#       "haircut_percentage": "8.00%"
#     },
#     {
#       "name": "Belgian Government Bond",
#       "tenure_min": "> 17yrs <=",
#       "tenure_max": "<= 55yrs",
#       "haircut_percentage": "13.75%"
#     },
#     {
#       "name": "Canadian Treasury Bill",
#       "tenure_min": "15 calendar days <=",
#       "tenure_max": "<= 2yr",
#       "haircut_percentage": "0.97%"
#     },
#     {
#       "name": "Canadian Government Bond",
#       "tenure_min": "> 2yr <=",
#       "tenure_max": "<= 5yrs",
#       "haircut_percentage": "1.37%"
#     },
#     {
#       "name": "Canadian Government Bond",
#       "tenure_min": "> 5yrs <=",
#       "tenure_max": "<= 8yrs",
#       "haircut_percentage": "2.56%"
#     },
#     {
#       "name": "Canada Government Real Return Bond",
#       "tenure_min": ">8yrs <=",
#       "tenure_max": "<= 10yrs",
#       "haircut_percentage": "3.79%"
#     },
#     {
#       "name": "Canada Government Real Return Bond",
#       "tenure_min": "> 10yrs <=",
#       "tenure_max": "<= 35yrs",
#       "haircut_percentage": "7.85%"
#     },
#     {
#       "name": "Danish Treasury Bill",
#       "tenure_min": "8 business days <=",
#       "tenure_max": "<= 2yr",
#       "haircut_percentage": "0.58%"
#     },
#     {
#       "name": "Danish Government Bond",
#       "tenure_min": "> 2yr <=",
#       "tenure_max": "<= 6yrs",
#       "haircut_percentage": "1.69%"
#     },
#     {
#       "name": "Danish Government Bond",
#       "tenure_min": ">6yrs <=",
#       "tenure_max": "<= 9yrs",
#       "haircut_percentage": "2.58%"
#     },
#     {
#       "name": "Danish Government I/L",
#       "tenure_min": ">9yrs <=",
#       "tenure_max": "<= 13yrs",
#       "haircut_percentage": "2.73%"
#     },
#     {
#       "name": "Danish Government I/L",
#       "tenure_min": ">13yrs <=",
#       "tenure_max": "<= 40yrs",
#       "haircut_percentage": "10.52%"
#     },
#     {
#       "name": "Danish Government I/L",
#       "tenure_min": "> 40yrs <=",
#       "tenure_max": "<= 60yrs",
#       "haircut_percentage": "6.87%"
#     },
#     {
#       "name": "Finnish Treasury Bill",
#       "tenure_min": "6 business days <=",
#       "tenure_max": "<= 2yr",
#       "haircut_percentage": "0.38%"
#     },
#     {
#       "name": "Finnish Government Bonds",
#       "tenure_min": "> 2yr <=",
#       "tenure_max": "<= 3yrs",
#       "haircut_percentage": "1.68%"
#     },
#     {
#       "name": "Finnish Government Bonds",
#       "tenure_min": ">3yrs <=",
#       "tenure_max": "<= 7 yrs",
#       "haircut_percentage": "2.71%"
#     },
#     {
#       "name": "Finnish Government Bonds",
#       "tenure_min": ">7yrs <=",
#       "tenure_max": "<= 12yrs",
#       "haircut_percentage": "3.62%"
#     },
#     {
#       "name": "Finnish Government Bonds",
#       "tenure_min": "> 12yrs <=",
#       "tenure_max": "<= 45yrs",
#       "haircut_percentage": "10.86%"
#     },
#     {
#       "name": "Finnish Government Bonds",
#       "tenure_min": "> 45yrs <=",
#       "tenure_max": "<= 65yrs",
#       "haircut_percentage": "13.98%"
#     },
#     {
#       "name": "Bons du Trésor à Taux Fixe et Intérêt Précompté",
#       "tenure_min": "6 business days <=",
#       "tenure_max": "<= 2yr",
#       "haircut_percentage": "0.47%"
#     },
#     {
#       "name": "Bons du Trésor à Taux Fixe et Intérêt Précompté",
#       "tenure_min": ">2yr <=",
#       "tenure_max": "<= 3yrs",
#       "haircut_percentage": "1.89%"
#     },
#     {
#       "name": "Bons du Trésor à Taux Fixe et Intérêt Annuel",
#       "tenure_min": ">3yrs <=",
#       "tenure_max": "<= 7 yrs",
#       "haircut_percentage": "3.55%"
#     },
#     {
#       "name": "Bons du Trésor à Taux Fixe et Intérêt Annuel",
#       "tenure_min": "> 7yrs <=",
#       "tenure_max": "<= 13yrs",
#       "haircut_percentage": "12.66%"
#     },
#     {
#       "name": "Bons du Trésor à Taux Fixe et Intérêt Annuel I/L",
#       "tenure_min": ">13yrs <=",
#       "tenure_max": "<= 45yrs",
#       "haircut_percentage": "14.88%"
#     },
#     {
#       "name": "Bons du Trésor à Taux Fixe et Intérêt Annuel I/L",
#       "tenure_min": "> 45yrs <=",
#       "tenure_max": "<= 65yrs",
#       "haircut_percentage": "16.44%"
#     },
#     {
#       "name": "German Treasury Bill",
#       "tenure_min": "13 business days <=",
#       "tenure_max": "<= 1yr",
#       "haircut_percentage": "0.88%"
#     },
#     {
#       "name": "German Treasury Bill",
#       "tenure_min": ">1yr <=",
#       "tenure_max": "<= 3yrs",
#       "haircut_percentage": "0.89%"
#     },
#     {
#       "name": "Bundesschatzanweisungen",
#       "tenure_min": ">3yrs <=",
#       "tenure_max": "<= 7 yrs",
#       "haircut_percentage": "2.77%"
#     },
#     {
#       "name": "Bundesschatzanweisungen",
#       "tenure_min": ">7yrs <=",
#       "tenure_max": "<= 13yrs",
#       "haircut_percentage": "3.85%"
#     },
#     {
#       "name": "Bundesobligationen",
#       "tenure_min": "> 12yrs <=",
#       "tenure_max": "<= 45yrs",
#       "haircut_percentage": "10.88%"
#     },
#     {
#       "name": "Bundesobligationen I/L",
#       "tenure_min": "> 45yrs <=",
#       "tenure_max": "<= 65yrs",
#       "haircut_percentage": "19.77%"
#     },
#     {
#       "name": "Buoni Ordinari del Tesoro",
#       "tenure_min": "13 business days <=",
#       "tenure_max": "<= 1yr",
#       "haircut_percentage": "2.95%"
#     },
#     {
#       "name": "Buoni del Tesoro Poliennali",
#       "tenure_min": "> 1yr <=",
#       "tenure_max": "<= 3yrs",
#       "haircut_percentage": "6.35%"
#     },
#     {
#       "name": "Buoni del Tesoro Poliennali",
#       "tenure_min": ">3yrs <=",
#       "tenure_max": "<= 7 yrs",
#       "haircut_percentage": "9.44%"
#     },
#     {
#       "name": "Buoni del Tesoro Poliennali",
#       "tenure_min": "> 7yrs <=",
#       "tenure_max": "<= 13yrs",
#       "haircut_percentage": "11.54%"
#     },
#     {
#       "name": "Buoni del Tesoro Poliennali",
#       "tenure_min": ">13yrs <=",
#       "tenure_max": "<= 45yrs",
#       "haircut_percentage": "15.78%"
#     },
#     {
#       "name": "Buoni del Tesoro Poliennali",
#       "tenure_min": "> 45yrs <=",
#       "tenure_max": "<= 65yrs",
#       "haircut_percentage": "28.55%"
#     },
#     {
#       "name": "Japanese Treasury Bill",
#       "tenure_min": "17 business days <=",
#       "tenure_max": "<= 1yr",
#       "haircut_percentage": "5.54%"
#     },
#     {
#       "name": "Japanese Treasury Discount Bill",
#       "tenure_min": ">1yr <=",
#       "tenure_max": "<= 3yrs",
#       "haircut_percentage": "7.78%"
#     },
#     {
#       "name": "Japanese Government Bond",
#       "tenure_min": ">3yrs <=",
#       "tenure_max": "<= 7 yrs",
#       "haircut_percentage": "9.99%"
#     },
#     {
#       "name": "Japanese Government Bond",
#       "tenure_min": ">7yrs <=",
#       "tenure_max": "<= 13yrs",
#       "haircut_percentage": "13.98%"
#     },
#     {
#       "name": "Japanese Government Bond",
#       "tenure_min": ">13yrs <=",
#       "tenure_max": "<= 45yrs",
#       "haircut_percentage": "16.87%"
#     },
#     {
#       "name": "Japanese Government Bond",
#       "tenure_min": "> 45yrs <=",
#       "tenure_max": "<= 65yrs",
#       "haircut_percentage": "27.88%"
#     },
#     {
#       "name": "Luxembougois Government Bonds",
#       "tenure_min": "45 business days <=",
#       "tenure_max": "<= 1yr",
#       "haircut_percentage": "0.79%"
#     },
#     {
#       "name": "Luxembougois Government Bonds",
#       "tenure_min": ">1yr <=",
#       "tenure_max": "<= 3yrs",
#       "haircut_percentage": "2.55%"
#     },
#     {
#       "name": "Luxembougois Government Bonds",
#       "tenure_min": ">3yrs <=",
#       "tenure_max": "<= 7 yrs",
#       "haircut_percentage": "4.78%"
#     },
#     {
#       "name": "Luxembougois Government Bonds",
#       "tenure_min": ">7yrs <=",
#       "tenure_max": "<= 13yrs",
#       "haircut_percentage": "5.98%"
#     },
#     {
#       "name": "Luxembougois Government Bonds",
#       "tenure_min": ">13yrs <=",
#       "tenure_max": "<= 45yrs",
#       "haircut_percentage": "6.55%"
#     },
#     {
#       "name": "Luxembougois Government Bonds",
#       "tenure_min": "> 45yrs <=",
#       "tenure_max": "<= 65yrs",
#       "haircut_percentage": "8.44%"
#     },
#     {
#       "name": "Dutch Treasury Certificate",
#       "tenure_min": "49 business days <=",
#       "tenure_max": "<= 1yr",
#       "haircut_percentage": "0.78%"
#     },
#     {
#       "name": "Dutch Treasury Certificate",
#       "tenure_min": ">1yr <=",
#       "tenure_max": "<= 3yrs",
#       "haircut_percentage": "0.95%"
#     },
#     {
#       "name": "Dutch Government Bond",
#       "tenure_min": ">3yrs <=",
#       "tenure_max": "<= 7 yrs",
#       "haircut_percentage": "2.65%"
#     },
#     {
#       "name": "Dutch Government Bond",
#       "tenure_min": ">7yrs <=",
#       "tenure_max": "<= 13yrs",
#       "haircut_percentage": "3.48%"
#     },
#     {
#       "name": "Dutch Government Bond",
#       "tenure_min": ">13yrs <=",
#       "tenure_max": "<= 45yrs",
#       "haircut_percentage": "4.98%"
#     },
#     {
#       "name": "Dutch Government Bond",
#       "tenure_min": "> 45yrs <=",
#       "tenure_max": "<= 65yrs",
#       "haircut_percentage": "7.63%"
#     },
#     {
#       "name": "Norwegian Treasury Bill",
#       "tenure_min": "29 business days <=",
#       "tenure_max": "<= 1yr",
#       "haircut_percentage": "0.47%"
#     },
#     {
#       "name": "Norwegian Treasury Bill",
#       "tenure_min": "> 1yr <=",
#       "tenure_max": "<= 3yrs",
#       "haircut_percentage": "3.45%"
#     },
#     {
#       "name": "Norwegian Government Bond",
#       "tenure_min": ">3yrs <=",
#       "tenure_max": "<= 7 yrs",
#       "haircut_percentage": "4.25%"
#     },
#     {
#       "name": "Singapore Treasury Bill",
#       "tenure_min": "35 business days <=",
#       "tenure_max": "<= 1yr",
#       "haircut_percentage": "2.70%"
#     },
#     {
#       "name": "Singapore Treasury Bill",
#       "tenure_min": ">1yr <=",
#       "tenure_max": "<= 3yrs",
#       "haircut_percentage": "3.25%"
#     },
#     {
#       "name": "Singapore Government Bonds",
#       "tenure_min": ">3yrs <=",
#       "tenure_max": "<= 7 yrs",
#       "haircut_percentage": "4.78%"
#     },
#     {
#       "name": "Singapore Government Bonds",
#       "tenure_min": ">7yrs <=",
#       "tenure_max": "<= 13yrs",
#       "haircut_percentage": "5.66%"
#     },
#     {
#       "name": "Monetary Authority of Singapore Bill",
#       "tenure_min": ">13yrs <=",
#       "tenure_max": "<= 45yrs",
#       "haircut_percentage": "16.50%"
#     },
#     {
#       "name": "Spanish Letras del Tesoro",
#       "tenure_min": "37 business days <=",
#       "tenure_max": "<= 1yr",
#       "haircut_percentage": "1.63%"
#     },
#     {
#       "name": "Spanish Letras del Tesoro",
#       "tenure_min": ">1yr <=",
#       "tenure_max": "<= 3yrs",
#       "haircut_percentage": "5.13%"
#     },
#     {
#       "name": "Spanish Government Bond",
#       "tenure_min": ">3yrs <=",
#       "tenure_max": "<= 7 yrs",
#       "haircut_percentage": "6.13%"
#     },
#     {
#       "name": "Spanish Government Bond",
#       "tenure_min": ">7yrs <=",
#       "tenure_max": "<= 13yrs",
#       "haircut_percentage": "15.38%"
#     },
#     {
#       "name": "Spanish Government Bond",
#       "tenure_min": "> 13yrs <=",
#       "tenure_max": "<= 45yrs",
#       "haircut_percentage": "19.25%"
#     },
#     {
#       "name": "Spanish Government Bond",
#       "tenure_min": "> 45yrs <=",
#       "tenure_max": "<= 65yrs",
#       "haircut_percentage": "25.75%"
#     },
#     {
#       "name": "Swedish Treasury Bill",
#       "tenure_min": "64 business days <=",
#       "tenure_max": "<= 1yr",
#       "haircut_percentage": "0.98%"
#     },
#     {
#       "name": "Swedish Treasury Bill",
#       "tenure_min": ">1yr <=",
#       "tenure_max": "<= 3yrs",
#       "haircut_percentage": "1.48%"
#     },
#     {
#       "name": "Swedish Government Bond",
#       "tenure_min": ">3yrs <=",
#       "tenure_max": "<= 7 yrs",
#       "haircut_percentage": "2.57%"
#     },
#     {
#       "name": "Swedish Government Bond",
#       "tenure_min": ">7yrs <=",
#       "tenure_max": "<= 13yrs",
#       "haircut_percentage": "3.98%"
#     },
#     {
#       "name": "Swiss Treasury Bill",
#       "tenure_min": "37 business days <=",
#       "tenure_max": "<= 1yr",
#       "haircut_percentage": "0.78%"
#     },
#     {
#       "name": "Swiss Treasury Bill",
#       "tenure_min": ">1yr <=",
#       "tenure_max": "<= 3yrs",
#       "haircut_percentage": "0.87%"
#     },
#     {
#       "name": "Swiss Government Bond",
#       "tenure_min": ">3yrs <=",
#       "tenure_max": "<= 7 yrs",
#       "haircut_percentage": "2.73%"
#     },
#     {
#       "name": "Swiss Government Bond",
#       "tenure_min": ">7yrs <=",
#       "tenure_max": "<= 13yrs",
#       "haircut_percentage": "2.90%"
#     },
#     {
#       "name": "Swiss Government Bond",
#       "tenure_min": ">13yrs <=",
#       "tenure_max": "<= 45yrs",
#       "haircut_percentage": "3.59%"
#     },
#     {
#       "name": "United Kingdom Treasury Bill",
#       "tenure_min": "90 business days <=",
#       "tenure_max": "<= 1yr",
#       "haircut_percentage": "0.25%"
#     },
#     {
#       "name": "United Kingdom Treasury Bill",
#       "tenure_min": ">1yr <=",
#       "tenure_max": "<= 3yrs",
#       "haircut_percentage": "1.30%"
#     },
#     {
#       "name": "United Kingdom Gilt",
#       "tenure_min": ">3yrs <=",
#       "tenure_max": "<= 7 yrs",
#       "haircut_percentage": "2.30%"
#     },
#     {
#       "name": "United Kingdom Index Linked Gilt",
#       "tenure_min": ">7yrs <=",
#       "tenure_max": "<= 13yrs",
#       "haircut_percentage": "3.50%"
#     },
#     {
#       "name": "United Kingdom Index Linked Gilt",
#       "tenure_min": ">13yrs <=",
#       "tenure_max": "<= 45yrs",
#       "haircut_percentage": "10.50%"
#     },
#     {
#       "name": "United Kingdom Index Linked Gilt",
#       "tenure_min": "> 45yrs",
#       "tenure_max": "NA",
#       "haircut_percentage": "16.63%"
#     },
#     {
#       "name": "United States Treasury Bill",
#       "tenure_min": "13 business days <=",
#       "tenure_max": "<= 1yr",
#       "haircut_percentage": "0.78%"
#     },
#     {
#       "name": "United States Treasury Bill",
#       "tenure_min": ">1yr <=",
#       "tenure_max": "<= 3yrs",
#       "haircut_percentage": "1.75%"
#     },
#     {
#       "name": "United States Cash Management Bill",
#       "tenure_min": ">3yrs <=",
#       "tenure_max": "<= 7 yrs",
#       "haircut_percentage": "2.98%"
#     },
#     {
#       "name": "United States Cash Management Bill",
#       "tenure_min": ">7yrs <=",
#       "tenure_max": "<= 13yrs",
#       "haircut_percentage": "3.88%"
#     },
#     {
#       "name": "United States Treasury Bond",
#       "tenure_min": ">13yrs <=",
#       "tenure_max": "<= 45yrs",
#       "haircut_percentage": "8.78%"
#     },
#     {
#       "name": "Network Rail Infrastructure Finance Plc",
#       "tenure_min": "69 business days <=",
#       "tenure_max": "<= 1yr",
#       "haircut_percentage": "0.44%"
#     },
#     {
#       "name": "Network Rail Infrastructure Finance Plc",
#       "tenure_min": ">1yr <=",
#       "tenure_max": "<= 3yrs",
#       "haircut_percentage": "2.59%"
#     },
#     {
#       "name": "Network Rail Infrastructure Finance Plc",
#       "tenure_min": "> 3yrs <=",
#       "tenure_max": "<= 7 yrs",
#       "haircut_percentage": "3.00%"
#     },
#     {
#       "name": "Network Rail Infrastructure Finance Plc",
#       "tenure_min": ">7yrs <=",
#       "tenure_max": "<= 13yrs",
#       "haircut_percentage": "4.50%"
#     },
#     {
#       "name": "Network Rail Infrastructure Finance Plc",
#       "tenure_min": ">13yrs <=",
#       "tenure_max": "<= 45yrs",
#       "haircut_percentage": "12.80%"
#     },
#     {
#       "name": "Kreditanstalt für Wiederaufbau",
#       "tenure_min": "73 business days <=",
#       "tenure_max": "<= 1yr",
#       "haircut_percentage": "0.76%"
#     },
#     {
#       "name": "Kreditanstalt für Wiederaufbau",
#       "tenure_min": ">1yr <=",
#       "tenure_max": "<= 3yrs",
#       "haircut_percentage": "1.34%"
#     },
#     {
#       "name": "FMS Wertmanagement",
#       "tenure_min": ">3yrs <=",
#       "tenure_max": "<= 7 yrs",
#       "haircut_percentage": "11.77%"
#     },
#     {
#       "name": "FMS Wertmanagement",
#       "tenure_min": ">7yrs <=",
#       "tenure_max": "<= 13yrs",
#       "haircut_percentage": "13.45%"
#     },
#     {
#       "name": "FMS Wertmanagement",
#       "tenure_min": ">13yrs <=",
#       "tenure_max": "<= 45yrs",
#       "haircut_percentage": "19.48%"
#     },
#     {
#       "name": "Rentenbank",
#       "tenure_min": "82 business days <=",
#       "tenure_max": "<= 1yr",
#       "haircut_percentage": "8.53%"
#     },
#     {
#       "name": "Rentenbank",
#       "tenure_min": ">1yr <=",
#       "tenure_max": "<= 3yrs",
#       "haircut_percentage": "12.35%"
#     },
#     {
#       "name": "Rentenbank",
#       "tenure_min": ">3yrs <=",
#       "tenure_max": "<= 7 yrs",
#       "haircut_percentage": "13.50%"
#     },
#     {
#       "name": "Caisse d'Amortissement de la Dette Sociale",
#       "tenure_min": "91 business days <=",
#       "tenure_max": "<= 1yr",
#       "haircut_percentage": "0.64%"
#     },
#     {
#       "name": "Caisse d'Amortissement de la Dette Sociale",
#       "tenure_min": ">3yrs <=",
#       "tenure_max": "<= 7 yrs",
#       "haircut_percentage": "4.55%"
#     },
#     {
#       "name": "Federal National Mortgage Association",
#       "tenure_min": "43 business days <=",
#       "tenure_max": "<= 1yr",
#       "haircut_percentage": "0.78%"
#     },
#     {
#       "name": "Federal National Mortgage Association",
#       "tenure_min": ">1yr <=",
#       "tenure_max": "<= 3yrs",
#       "haircut_percentage": "1.44%"
#     },
#     {
#       "name": "Federal National Mortgage Association",
#       "tenure_min": ">3yrs <=",
#       "tenure_max": "<= 7 yrs",
#       "haircut_percentage": "3.88%"
#     },
#     {
#       "name": "Federal Home Loan Mortgage Corporation",
#       "tenure_min": ">7yrs <=",
#       "tenure_max": "<= 13yrs",
#       "haircut_percentage": "4.55%"
#     },
#     {
#       "name": "Kommuninvest I Sverige",
#       "tenure_min": "36 business days <=",
#       "tenure_max": "<= 1yr",
#       "haircut_percentage": "15.00%"
#     },
#     {
#       "name": "Kommuninvest I Sverige",
#       "tenure_min": ">1yr <=",
#       "tenure_max": "<= 3yrs",
#       "haircut_percentage": "16.00%"
#     },
#     {
#       "name": "Kommuninvest I Sverige",
#       "tenure_min": ">3yrs <=",
#       "tenure_max": "<= 7 yrs",
#       "haircut_percentage": "17.00%"
#     },
#     {
#       "name": "Kommuninvest I Sverige",
#       "tenure_min": ">7yrs <=",
#       "tenure_max": "<= 13yrs",
#       "haircut_percentage": "18.00%"
#     },
#     {
#       "name": "Kommuninvest I Sverige",
#       "tenure_min": ">13yrs <=",
#       "tenure_max": "<= 45yrs",
#       "haircut_percentage": "19.00%"
#     },
#     {
#       "name": "General National Mortgage Association",
#       "tenure_min": "New (0 - 30 months)",
#       "tenure_max": "Medium (30- 60 months)",
#       "haircut_percentage": "22.00%"
#     },
#     {
#       "name": "General National Mortgage Association",
#       "tenure_min": "Medium (30- 60 months)",
#       "tenure_max": "Seasoned (> 60 months)",
#       "haircut_percentage": "24.50%"
#     },
#     {
#       "name": "International Bank for Reconstruction & Development",
#       "tenure_min": "42 business days <=",
#       "tenure_max": "<= 1yr",
#       "haircut_percentage": "1.25%"
#     },
#     {
#       "name": "International Bank for Reconstruction & Development",
#       "tenure_min": ">1yr <=",
#       "tenure_max": "<= 3yrs",
#       "haircut_percentage": "2.25%"
#     },
#     {
#       "name": "International Bank for Reconstruction & Development",
#       "tenure_min": ">3yrs <=",
#       "tenure_max": "<= 7 yrs",
#       "haircut_percentage": "4.35%"
#     },
#     {
#       "name": "International Bank for Reconstruction & Development",
#       "tenure_min": ">7yrs <=",
#       "tenure_max": "<= 13yrs",
#       "haircut_percentage": "8.88%"
#     },
#     {
#       "name": "European Investment Bank",
#       "tenure_min": "99 business days <=",
#       "tenure_max": "<= 1yr",
#       "haircut_percentage": "2.75%"
#     },
#     {
#       "name": "European Investment Bank",
#       "tenure_min": ">1yr <=",
#       "tenure_max": "<= 3yrs",
#       "haircut_percentage": "4.00%"
#     },
#     {
#       "name": "European Investment Bank",
#       "tenure_min": ">3yrs <=",
#       "tenure_max": "<= 7 yrs",
#       "haircut_percentage": "6.75%"
#     },
#     {
#       "name": "European Investment Bank",
#       "tenure_min": ">7yrs <=",
#       "tenure_max": "<= 13yrs",
#       "haircut_percentage": "13.50%"
#     },
#     {
#       "name": "European Investment Bank",
#       "tenure_min": ">13yrs <=",
#       "tenure_max": "<= 45yrs",
#       "haircut_percentage": "18.75%"
#     },
#     {
#       "name": "European Stability Facility Mechanism",
#       "tenure_min": "63 business days <=",
#       "tenure_max": "<= 1yr",
#       "haircut_percentage": "10.50%"
#     },
#     {
#       "name": "European Stability Facility Mechanism",
#       "tenure_min": ">1yr <=",
#       "tenure_max": "<= 3yrs",
#       "haircut_percentage": "12.00%"
#     },
#     {
#       "name": "European Stability Facility Mechanism",
#       "tenure_min": ">3yrs <=",
#       "tenure_max": "<= 7 yrs",
#       "haircut_percentage": "13.50%"
#     },
#     {
#       "name": "European Stability Facility Mechanism",
#       "tenure_min": ">7yrs <=",
#       "tenure_max": "<= 13yrs",
#       "haircut_percentage": "16.50%"
#     },
#     {
#       "name": "European Bank for Reconstruction & Development",
#       "tenure_min": "27 business days <=",
#       "tenure_max": "<= 1yr",
#       "haircut_percentage": "0.75%"
#     },
#     {
#       "name": "European Union",
#       "tenure_min": "32 business days <=",
#       "tenure_max": "<= 1yr",
#       "haircut_percentage": "0.75%"
#     },
#     {
#       "name": "European Union",
#       "tenure_min": ">1yr <=",
#       "tenure_max": "<= 3yrs",
#       "haircut_percentage": "1.50%"
#     },
#     {
#       "name": "European Union",
#       "tenure_min": ">3yrs <=",
#       "tenure_max": "<= 7 yrs",
#       "haircut_percentage": "2.50%"
#     },
#     {
#       "name": "European Union",
#       "tenure_min": ">7yrs <=",
#       "tenure_max": "<= 13yrs",
#       "haircut_percentage": "3.50%"
#     },
#     {
#       "name": "European Union",
#       "tenure_min": "> 13yrs <=",
#       "tenure_max": "<= 45yrs",
#       "haircut_percentage": "18.50%"
#     },
#     {
#       "name": "European Union",
#       "tenure_min": "> 45yrs <=",
#       "tenure_max": "<= 65yrs",
#       "haircut_percentage": "45.89%"
#     }
#   ]
# }
